# %% [markdown]
# # Jason Hsiao

# %% [markdown]
# ## Research question/interests
# This dataset has the mean temperature for Kelowna on Jan.01 each year and the prediction for the future. We are looking for the connection between the impact of different amount of emmisions of CO2 (carbon dioxide) and the mean temperature.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
meanTemp = pd.read_csv('../data/raw/Mean_Temperature.csv')

# %%
meanTemp
# Out:
#        DateTime  Modeled Historical  Historical Range (low)  \
# 0    1950-01-01                8.57                    7.63
# 1    1951-01-01                8.53                    7.94
# 2    1952-01-01                8.33                    7.37
# 3    1953-01-01                8.24                    7.75
# 4    1954-01-01                8.20                    7.63
# ..          ...                 ...                     ...
# 146  2096-01-01                 NaN                     NaN
# 147  2097-01-01                 NaN                     NaN
# 148  2098-01-01                 NaN                     NaN
# 149  2099-01-01                 NaN                     NaN
# 150  2100-01-01                 NaN                     NaN
#
#      Historical Range (high)  RCP 2.6 Median  RCP 2.6 Range (low)  \
# 0                       9.38             NaN                  NaN
# 1                       9.52             NaN                  NaN
# ...

# %%
#Clean up the DateTime column
i=1950
for x in range(151):
    meanTemp["DateTime"][x]=i
    i=i+1
meanTemp
# Out:
# C:\Users\JASONH~1\AppData\Local\Temp/ipykernel_15404/2628342126.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meanTemp["DateTime"][x]=i
#     DateTime  Modeled Historical  Historical Range (low)  \
# 0       1950                8.57                    7.63
# 1       1951                8.53                    7.94
# 2       1952                8.33                    7.37
# 3       1953                8.24                    7.75
# 4       1954                8.20                    7.63
# ..       ...                 ...                     ...
# 146     2096                 NaN                     NaN
# 147     2097                 NaN                     NaN
# 148     2098                 NaN                     NaN
# 149     2099                 NaN                     NaN
# ...

# %%
pastTemp=meanTemp[0:55]
pastTemp
# Out:
#    DateTime  Modeled Historical  Historical Range (low)  \
# 0      1950                8.57                    7.63
# 1      1951                8.53                    7.94
# 2      1952                8.33                    7.37
# 3      1953                8.24                    7.75
# 4      1954                8.20                    7.63
# 5      1955                8.43                    7.23
# 6      1956                8.31                    7.64
# 7      1957                8.09                    7.42
# 8      1958                8.03                    7.50
# 9      1959                8.08                    7.47
# 10     1960                8.25                    7.18
# 11     1961                8.54                    7.33
# 12     1962                8.35                    7.45
# 13     1963                8.23                    7.71
# 14     1964                8.02                    6.69
# 15     1965                8.13                    7.35
# ...

# %%
pastTemp.describe()
# Out:
#        Modeled Historical  Historical Range (low)  Historical Range (high)  \
# count           55.000000               55.000000                55.000000
# mean             8.478364                7.594364                 9.279636
# std              0.319819                0.348020                 0.360976
# min              7.880000                6.690000                 8.620000
# 25%              8.240000                7.360000                 9.015000
# 50%              8.470000                7.540000                 9.280000
# 75%              8.625000                7.770000                 9.510000
# max              9.460000                8.400000                10.170000
#
#        RCP 2.6 Median  RCP 2.6 Range (low)  RCP 2.6 Range (high)  \
# count             0.0                  0.0                   0.0
# mean              NaN                  NaN                   NaN
# std               NaN                  NaN                   NaN
# ...

# %%
print(pastTemp.columns.tolist())
# Out:
# ['DateTime', 'Modeled Historical', 'Historical Range (low)', 'Historical Range (high)', 'RCP 2.6 Median', 'RCP 2.6 Range (low)', 'RCP 2.6 Range (high)', 'RCP 4.5 Median', 'RCP 4.5 Range (low)', 'RCP 4.5 Range (high)', 'RCP 8.5 Median', 'RCP 8.5 Range (low)', 'RCP 8.5 Range (high)']

# %%
pastTemp.pop('RCP 2.6 Median')
pastTemp.pop('RCP 2.6 Range (low)')
pastTemp.pop('RCP 2.6 Range (high)')
pastTemp.pop('RCP 4.5 Median')
pastTemp.pop('RCP 4.5 Range (low)')
pastTemp.pop('RCP 4.5 Range (high)')
pastTemp.pop('RCP 8.5 Median')
pastTemp.pop('RCP 8.5 Range (low)')
pastTemp.pop('RCP 8.5 Range (high)')
pastTemp
# Out:
#    DateTime  Modeled Historical  Historical Range (low)  \
# 50     2000                8.96                    8.28
# 51     2001                8.98                    8.40
# 52     2002                9.46                    8.35
# 53     2003                9.05                    7.93
# 54     2004                9.04                    7.96
#
#     Historical Range (high)
# 50                     9.63
# 51                    10.03
# 52                     9.93
# 53                    10.17
# 54                    10.01

# %%
futureTemp=meanTemp[56:151]
futureTemp
# Out:
#     DateTime  Modeled Historical  Historical Range (low)  \
# 56      2006                 NaN                     NaN
# 57      2007                 NaN                     NaN
# 58      2008                 NaN                     NaN
# 59      2009                 NaN                     NaN
# 60      2010                 NaN                     NaN
# ..       ...                 ...                     ...
# 146     2096                 NaN                     NaN
# 147     2097                 NaN                     NaN
# 148     2098                 NaN                     NaN
# 149     2099                 NaN                     NaN
# 150     2100                 NaN                     NaN
#
#      Historical Range (high)  RCP 2.6 Median  RCP 2.6 Range (low)  \
# 56                       NaN            9.29                 8.39
# 57                       NaN            9.07                 8.38
# 58                       NaN            9.28                 8.37
# ...

# %%
#futureTemp.pop('Modeled Historical')
#futureTemp.pop('Historical Range (low)')
#futureTemp.pop('Historical Range (high)')
futureTemp
# Out:
#     DateTime  RCP 2.6 Median  RCP 2.6 Range (low)  RCP 2.6 Range (high)  \
# 56      2006            9.29                 8.39                  9.84
# 57      2007            9.07                 8.38                 10.22
# 58      2008            9.28                 8.37                 10.14
# 59      2009            9.59                 8.54                 10.38
# 60      2010            9.28                 8.62                 10.58
# ..       ...             ...                  ...                   ...
# 146     2096           10.41                 9.18                 11.79
# 147     2097           10.75                 9.71                 11.70
# 148     2098           10.21                 9.29                 11.60
# 149     2099           10.38                 9.44                 11.89
# 150     2100           10.78                 9.32                 11.65
#
#      RCP 4.5 Median  RCP 4.5 Range (low)  RCP 4.5 Range (high)  \
# ...

# %%
pastTemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DateTime                 55 non-null     object
#  1   Modeled Historical       55 non-null     float64
#  2   Historical Range (low)   55 non-null     float64
#  3   Historical Range (high)  55 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.8+ KB

# %%
#see if modeled historical mean temperature lies in between the other two
years=pastTemp['DateTime']
#pastTemp['DateTime'].plot()
plt.plot(years,pastTemp['Modeled Historical'],label='Historical')
plt.plot(years,pastTemp["Historical Range (low)"],label='Range(low)')
plt.plot(years,pastTemp['Historical Range (high)'],label='Range(high)')
plt.legend()
plt.ylabel('Degree')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
#select median columns to have a better look
futureTemp.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
def cleanYear(data):
    i=1950
    for x in range(151):
        data["DateTime"][x]=i
        i=i+1
    return data
def load(path):
    #m=pd.read_csv(path)
    df1=(
        pd.read_csv(path)
        .iloc[:55]
        .dropna(axis='columns', how='any')
    )
    return df1
p='../data/raw/Mean_Temperature.csv'
load(p)
# Out:
#       DateTime  Modeled Historical  Historical Range (low)  \
# 0   1950-01-01                8.57                    7.63
# 1   1951-01-01                8.53                    7.94
# 2   1952-01-01                8.33                    7.37
# 3   1953-01-01                8.24                    7.75
# 4   1954-01-01                8.20                    7.63
# 5   1955-01-01                8.43                    7.23
# 6   1956-01-01                8.31                    7.64
# 7   1957-01-01                8.09                    7.42
# 8   1958-01-01                8.03                    7.50
# 9   1959-01-01                8.08                    7.47
# 10  1960-01-01                8.25                    7.18
# 11  1961-01-01                8.54                    7.33
# 12  1962-01-01                8.35                    7.45
# 13  1963-01-01                8.23                    7.71
# 14  1964-01-01                8.02                    6.69
# ...

# %% [markdown]
# #
