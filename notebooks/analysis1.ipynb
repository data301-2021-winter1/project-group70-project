# %% [markdown]
# # Jason Hsiao

# %% [markdown]
# ## Research question/interests
# This dataset has the mean temperature for Kelowna on Jan.01 each year and the prediction for the future. We are looking for the connection between the impact of different amount of emmisions of CO2 (carbon dioxide) and the mean temperature.

# %%
import pandas as pd

# %%
meanTemp = pd.read_csv('../data/raw/Mean_Temperature.csv')

# %%
meanTemp
# Out:
#        DateTime  Modeled Historical  Historical Range (low)  \
# 0    1950-01-01                8.57                    7.63
# 1    1951-01-01                8.53                    7.94
# 2    1952-01-01                8.33                    7.37
# 3    1953-01-01                8.24                    7.75
# 4    1954-01-01                8.20                    7.63
# ..          ...                 ...                     ...
# 146  2096-01-01                 NaN                     NaN
# 147  2097-01-01                 NaN                     NaN
# 148  2098-01-01                 NaN                     NaN
# 149  2099-01-01                 NaN                     NaN
# 150  2100-01-01                 NaN                     NaN
#
#      Historical Range (high)  RCP 2.6 Median  RCP 2.6 Range (low)  \
# 0                       9.38             NaN                  NaN
# 1                       9.52             NaN                  NaN
# ...
