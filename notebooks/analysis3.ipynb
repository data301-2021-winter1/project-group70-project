# %% [markdown]
# # Pyper Legge

# %% [markdown]
# ## Research question/interests
# I will be looking in to how the severity of the hottest day will change in the different carbon emission scenarios.

# %%
import pandas as pd

# %%
hottestday = pd.read_csv ('../data/raw/Hottest_Day.csv')
i=1950
for x in range(151):
    hottestday["DateTime"][x]=i
    i=i+1
hottestday=hottestday.rename(columns={"DateTime": "Year"})
# cleaned up the years
# Out:
# <ipython-input-37-df0882f7b0c5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hottestday["DateTime"][x]=i

# %%
#import of raw data
hottestday
# Out:
#      Year  Modeled Historical  Historical Range (low)  \
# 0    1950               34.50                   33.29
# 1    1951               34.77                   33.43
# 2    1952               34.72                   33.35
# 3    1953               34.22                   32.81
# 4    1954               34.32                   33.08
# ..    ...                 ...                     ...
# 146  2096                 NaN                     NaN
# 147  2097                 NaN                     NaN
# 148  2098                 NaN                     NaN
# 149  2099                 NaN                     NaN
# 150  2100                 NaN                     NaN
#
#      Historical Range (high)  RCP 2.6 Median  RCP 2.6 Range (low)  \
# 0                      39.33             NaN                  NaN
# 1                      36.47             NaN                  NaN
# 2                      36.84             NaN                  NaN
# ...

# %% [markdown]
# ## Task 1

# %%
hottestday.columns
#here are the different columns, I will be removing all of the range data
# Out:
# Index(['Year', 'Modeled Historical', 'Historical Range (low)',
#        'Historical Range (high)', 'RCP 2.6 Median', 'RCP 2.6 Range (low)',
#        'RCP 2.6 Range (high)', 'RCP 4.5 Median', 'RCP 4.5 Range (low)',
#        'RCP 4.5 Range (high)', 'RCP 8.5 Median', 'RCP 8.5 Range (low)',
#        'RCP 8.5 Range (high)'],
#       dtype='object')

# %%
hottestday.describe()
#raw data stats
# Out:
#        Modeled Historical  Historical Range (low)  Historical Range (high)  \
# count           56.000000               56.000000                56.000000
# mean            34.773214               33.091607                37.160714
# std              0.633286                0.650719                 0.890466
# min             33.590000               31.910000                35.630000
# 25%             34.317500               32.622500                36.560000
# 50%             34.665000               33.080000                37.140000
# 75%             35.080000               33.465000                37.585000
# max             36.530000               34.680000                39.330000
#
#        RCP 2.6 Median  RCP 2.6 Range (low)  RCP 2.6 Range (high)  \
# count       96.000000            96.000000             96.000000
# mean        36.807708            34.709479             39.384271
# std          0.577846             0.608230              0.844981
# ...

# %%
# the stats for the data look solid.
# shows that as carbon emmisions increase the std of the hottest day temp also increases

# %%
# here are some graphs that show the different RCP senarios

# %%
hottestday.plot(kind='line', x='Year', y='RCP 8.5 Median')
#this shows the hottest day temp contuiniting to rise
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
hottestday.plot(kind='line', x='Year', y='RCP 4.5 Median')
#this shows the hottest day temp rising and then slightly plateauing
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
hottestday.plot(kind='line', x='Year', y='RCP 2.6 Median')
#this shows the hottest day temp rising and then dipping
#this shows our best case senario
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ## task 2

# %%
# cleaning up the dates on the raw data
# splitting hist data from projected data
# and cleaning both by removing blank data and the range data.

# %%
import pandas as pd
hottestday = pd.read_csv ('../data/raw/Hottest_Day.csv')
i=1950
for x in range(151):
    hottestday["DateTime"][x]=i
    i=i+1
hottestday=hottestday.rename(columns={"DateTime": "Year"})

hotday_proj = hottestday[56:151]
hotday_hist = hottestday[0:55]

hotday_proj_clean=hotday_proj.dropna(axis='columns',how='all')
hotday_proj_clean.pop('RCP 2.6 Range (low)')
hotday_proj_clean.pop('RCP 2.6 Range (high)')
hotday_proj_clean.pop('RCP 4.5 Range (low)')
hotday_proj_clean.pop('RCP 4.5 Range (high)')
hotday_proj_clean.pop('RCP 8.5 Range (low)')
hotday_proj_clean.pop('RCP 8.5 Range (high)')
hotday_hist_clean=hotday_hist.dropna(axis='columns',how='all')
hotday_hist_clean.pop('Historical Range (low)')
hotday_hist_clean.pop('Historical Range (high)')
hotday_hist_clean
# Out:
# <ipython-input-72-ec4a2594f920>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hottestday["DateTime"][x]=i
#     Year  Modeled Historical
# 0   1950               34.50
# 1   1951               34.77
# 2   1952               34.72
# 3   1953               34.22
# 4   1954               34.32
# 5   1955               34.71
# 6   1956               34.91
# 7   1957               35.14
# 8   1958               34.67
# 9   1959               34.19
# 10  1960               33.98
# 11  1961               33.96
# 12  1962               33.78
# 13  1963               34.63
# 14  1964               33.93
# 15  1965               34.42
# 16  1966               34.55
# 17  1967               33.59
# 18  1968               34.65
# 19  1969               34.20
# 20  1970               34.25
# ...

# %%
hotday_proj_clean
# Out:
#      Year  RCP 2.6 Median  RCP 4.5 Median  RCP 8.5 Median
# 56   2006           35.33           35.36           36.10
# 57   2007           35.53           36.80           36.68
# 58   2008           35.28           36.30           35.84
# 59   2009           36.20           36.03           35.71
# 60   2010           36.02           36.02           36.07
# ..    ...             ...             ...             ...
# 146  2096           37.00           39.48           43.03
# 147  2097           36.65           39.02           43.49
# 148  2098           36.33           39.60           43.41
# 149  2099           36.54           38.60           43.76
# 150  2100           36.69           39.59           44.22
#
# [95 rows x 4 columns]

# %%
hotday_hist_clean.describe()
# Out:
#        Modeled Historical
# count           55.000000
# mean            34.757455
# std              0.627943
# min             33.590000
# 25%             34.315000
# 50%             34.660000
# 75%             35.055000
# max             36.530000

# %%
hotday_proj_clean.describe()
# shows that as carbon emmisions increase the std of the hottest day temp also increases
# this also shows that the mean temp increases with each increase in carbon emmissions
# Out:
#        RCP 2.6 Median  RCP 4.5 Median  RCP 8.5 Median
# count       95.000000       95.000000       95.000000
# mean        36.820000       37.830737       39.293368
# std          0.568155        1.206380        2.436465
# min         35.280000       35.360000       35.710000
# 25%         36.530000       36.650000       37.200000
# 50%         36.820000       38.140000       39.170000
# 75%         37.200000       38.760000       41.235000
# max         38.140000       39.740000       44.220000

# %% [markdown]
# ## task 3

# %%
#chain for hist data
import pandas as pd
import numpy as np
hottestday = pd.read_csv ('../data/raw/Hottest_Day.csv') # this a data file that gets loaded
path = '../data/raw/Hottest_Day.csv'
# Method chaining begins


df = (   
   pd.read_csv(path)
      
           [0:55]
            .dropna(axis='columns',how='all')
            .drop(columns=["Historical Range (high)","Historical Range (low)"])
)

df
# Out:
#       DateTime  Modeled Historical
# 0   1950-01-01               34.50
# 1   1951-01-01               34.77
# 2   1952-01-01               34.72
# 3   1953-01-01               34.22
# 4   1954-01-01               34.32
# 5   1955-01-01               34.71
# 6   1956-01-01               34.91
# 7   1957-01-01               35.14
# 8   1958-01-01               34.67
# 9   1959-01-01               34.19
# 10  1960-01-01               33.98
# 11  1961-01-01               33.96
# 12  1962-01-01               33.78
# 13  1963-01-01               34.63
# 14  1964-01-01               33.93
# 15  1965-01-01               34.42
# 16  1966-01-01               34.55
# 17  1967-01-01               33.59
# 18  1968-01-01               34.65
# 19  1969-01-01               34.20
# 20  1970-01-01               34.25
# 21  1971-01-01               34.29
# 22  1972-01-01               34.04
# 23  1973-01-01               34.38
# 24  1974-01-01               33.89
# 25  1975-01-01               34.74
# ...

# %%
#chain for projected data
import pandas as pd
import numpy as np
hottestday = pd.read_csv ('../data/raw/Hottest_Day.csv') # this a data file that gets loaded
path = '../data/raw/Hottest_Day.csv'
# Method chaining begins


df = (   
   pd.read_csv(path)
      
           [56:151]
            .dropna(axis='columns',how='all')
            .drop(columns=["RCP 8.5 Range (high)","RCP 8.5 Range (low)","RCP 4.5 Range (high)","RCP 4.5 Range (low)","RCP 2.6 Range (high)","RCP 2.6 Range (low)"])
)

df
# Out:
#        DateTime  RCP 2.6 Median  RCP 4.5 Median  RCP 8.5 Median
# 56   2006-01-01           35.33           35.36           36.10
# 57   2007-01-01           35.53           36.80           36.68
# 58   2008-01-01           35.28           36.30           35.84
# 59   2009-01-01           36.20           36.03           35.71
# 60   2010-01-01           36.02           36.02           36.07
# ..          ...             ...             ...             ...
# 146  2096-01-01           37.00           39.48           43.03
# 147  2097-01-01           36.65           39.02           43.49
# 148  2098-01-01           36.33           39.60           43.41
# 149  2099-01-01           36.54           38.60           43.76
# 150  2100-01-01           36.69           39.59           44.22
#
# [95 rows x 4 columns]

# %%
#step 3
import pandas as pd
def cleanYear(data):
    i=1950
    for x in range(151):
        data['Year'][x]=i
        i=i+1
    return data

path='../data/raw/Hottest_Day.csv'
def load_and_process(path):
    # Method Chain 1 (hist data processing)

    hist= (
         pd.read_csv(path)
      
           [0:55]
            .dropna(axis='columns',how='all')
            .drop(columns=["Historical Range (high)","Historical Range (low)"])
            .rename(columns={"DateTime": "Year"})
      
      )

    # Method Chain 2 (projected data processing)

    proj= (
         
          pd.read_csv(path)
      
           [56:151]
            .dropna(axis='columns',how='all')
            .drop(columns=["RCP 8.5 Range (high)","RCP 8.5 Range (low)","RCP 4.5 Range (high)","RCP 4.5 Range (low)","RCP 2.6 Range (high)","RCP 2.6 Range (low)"])
            .rename(columns={"DateTime": "Year"})
      )
    hist=cleanYear(hist)
    proj=cleanYear(proj)
    return (hist, proj)

# %%
hist,proj=load_and_process('../data/raw/Hottest_Day.csv')
 
hist
# Out:
# <ipython-input-83-c4ccb77a8f53>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'][x]=i
#     Year  Modeled Historical
# 0   1950               34.50
# 1   1951               34.77
# 2   1952               34.72
# 3   1953               34.22
# 4   1954               34.32
# 5   1955               34.71
# 6   1956               34.91
# 7   1957               35.14
# 8   1958               34.67
# 9   1959               34.19
# 10  1960               33.98
# 11  1961               33.96
# 12  1962               33.78
# 13  1963               34.63
# 14  1964               33.93
# 15  1965               34.42
# 16  1966               34.55
# 17  1967               33.59
# 18  1968               34.65
# 19  1969               34.20
# 20  1970               34.25
# ...

# %%
proj
# Out:
#      Year  RCP 2.6 Median  RCP 4.5 Median  RCP 8.5 Median
# 56   2006           35.33           35.36           36.10
# 57   2007           35.53           36.80           36.68
# 58   2008           35.28           36.30           35.84
# 59   2009           36.20           36.03           35.71
# 60   2010           36.02           36.02           36.07
# ..    ...             ...             ...             ...
# 146  2096           37.00           39.48           43.03
# 147  2097           36.65           39.02           43.49
# 148  2098           36.33           39.60           43.41
# 149  2099           36.54           38.60           43.76
# 150  2100           36.69           39.59           44.22
#
# [95 rows x 4 columns]

# %% [markdown]
# ## Task 4

# %% [markdown]
# With the recent devastating heat waves in the Pacific Northwest, the realities of what our future climate will look like has become more apparent than ever. On our current path we can expect increased frequency and intensity of these dangerous heat waves. This data shows that the hottest day of the year will generally continue to increase in temperature regardless of what future steps we take due to the emissions already in our atmosphere. We have already gone past the point of no return when it comes to our climate. Although it is still important to low our emissions as out of the possible scenarios it is still better the reduce our emissions greatly compared to the scenarios where nothing is done.

# %%
proj.plot(kind='line', x='Year', y='RCP 8.5 Median')
#this shows the hottest day temp contuiniting to rise
#the hottest day temp peaks at about 44 degrees celsius
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# This shows the hottest day temp contuiniting to rise. The hottest day temp peaks at about 44 degrees celsius.

# %%
proj.plot(kind='line', x='Year', y='RCP 4.5 Median')
#this shows the hottest day temp rising and then slightly plateauing
#the hottest day temp peaks at about 40 degrees celsius
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# This shows the hottest day temp rising and then slightly plateauing. The hottest day temp peaks at about 40 degrees celsius.

# %%
proj.plot(kind='line', x='Year', y='RCP 2.6 Median')
#this shows the hottest day temp rising and then dipping
#the hottest day temp peaks at about 38 degrees celsius
#this shows our best case senario
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# this shows the hottest day temp rising and then dipping. The hottest day temp peaks at about 38 degrees celsius. This shows our best case senario.

# %%
hist.plot(kind='line', x='Year', y='Modeled Historical')
#it shows a slight up tick with a lower range compared to the future senarios
#the hottest day temp peaks at about 36.5 degrees celsius
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# This graph shows a slight up tick with a lower range compared to the future senarios. The hottest day temp peaks at about 36.5 degrees celsius.
