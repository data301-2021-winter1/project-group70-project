# %% [markdown]
# # Pyper Legge

# %% [markdown]
# ## Research question/interests
# I will be looking in to how the severity of the hottest day will change in the different carbon emission scenarios.

# %%
import pandas as pd

# %%
hottestday = pd.read_csv ('../data/raw/Hottest_Day.csv')

# %%
hottestday
# Out:
#        DateTime  Modeled Historical  Historical Range (low)  \
# 0    1950-01-01               34.50                   33.29
# 1    1951-01-01               34.77                   33.43
# 2    1952-01-01               34.72                   33.35
# 3    1953-01-01               34.22                   32.81
# 4    1954-01-01               34.32                   33.08
# ..          ...                 ...                     ...
# 146  2096-01-01                 NaN                     NaN
# 147  2097-01-01                 NaN                     NaN
# 148  2098-01-01                 NaN                     NaN
# 149  2099-01-01                 NaN                     NaN
# 150  2100-01-01                 NaN                     NaN
#
#      Historical Range (high)  RCP 2.6 Median  RCP 2.6 Range (low)  \
# 0                      39.33             NaN                  NaN
# 1                      36.47             NaN                  NaN
# ...

# %% [markdown]
# ## task 1

# %%
hottestday.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   DateTime                 151 non-null    object
#  1   Modeled Historical       56 non-null     float64
#  2   Historical Range (low)   56 non-null     float64
#  3   Historical Range (high)  56 non-null     float64
#  4   RCP 2.6 Median           96 non-null     float64
#  5   RCP 2.6 Range (low)      96 non-null     float64
#  6   RCP 2.6 Range (high)     96 non-null     float64
#  7   RCP 4.5 Median           96 non-null     float64
#  8   RCP 4.5 Range (low)      96 non-null     float64
#  9   RCP 4.5 Range (high)     96 non-null     float64
#  10  RCP 8.5 Median           96 non-null     float64
#  11  RCP 8.5 Range (low)      96 non-null     float64
#  12  RCP 8.5 Range (high)     96 non-null     float64
# dtypes: float64(12), object(1)
# ...

# %%
hottestday.describe()
# Out:
#        Modeled Historical  Historical Range (low)  Historical Range (high)  \
# count           56.000000               56.000000                56.000000
# mean            34.773214               33.091607                37.160714
# std              0.633286                0.650719                 0.890466
# min             33.590000               31.910000                35.630000
# 25%             34.317500               32.622500                36.560000
# 50%             34.665000               33.080000                37.140000
# 75%             35.080000               33.465000                37.585000
# max             36.530000               34.680000                39.330000
#
#        RCP 2.6 Median  RCP 2.6 Range (low)  RCP 2.6 Range (high)  \
# count       96.000000            96.000000             96.000000
# mean        36.807708            34.709479             39.384271
# std          0.577846             0.608230              0.844981
# ...

# %%
hottestday.plot()
# Out:
# <AxesSubplot:>

# %%
hottestday.boxplot('Modeled Historical')
# Out:
# <AxesSubplot:>

# %%
hottestday.plot(kind='line', x='DateTime', y='RCP 8.5 Median')
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %%
hottestday.plot(kind='line', x='DateTime', y='RCP 4.5 Median')
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %%
hottestday.plot(kind='line', x='DateTime', y='RCP 2.6 Median')
# Out:
# <AxesSubplot:xlabel='DateTime'>

# %% [markdown]
# ## task 2
